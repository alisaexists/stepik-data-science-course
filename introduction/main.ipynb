# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('StudentsPerformance.csv')
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.iloc[0:5, 0:3]
# Out:
#    gender race/ethnicity parental level of education
# 0  female        group B           bachelor's degree
# 1  female        group C                some college
# 2  female        group B             master's degree
# 3    male        group A          associate's degree
# 4    male        group C                some college

# %%
df.iloc[[0, 2], [2, 5, -1]]
# Out:
#   parental level of education  math score  writing score
# 0           bachelor's degree          72             74
# 2             master's degree          90             93

# %%
df_with_names = df.iloc[[0, 3, 4]]

# %%
df_with_names.index = ["Cersei", "Masha", "Pasha"]
df_with_names
# Out:
#         gender race/ethnicity parental level of education         lunch  \
# Cersei  female        group B           bachelor's degree      standard
# Masha     male        group A          associate's degree  free/reduced
# Pasha     male        group C                some college      standard
#
#        test preparation course  math score  reading score  writing score
# Cersei                    none          72             72             74
# Masha                     none          47             57             44
# Pasha                     none          76             78             75

# %%
df_with_names.loc[['Masha', 'Cersei'], ['gender', 'lunch']]
# Out:
#         gender         lunch
# Masha     male  free/reduced
# Cersei  female      standard

# %%
df_with_names.iloc[:, 0]
# Out:
# Cersei    female
# Masha       male
# Pasha       male
# Name: gender, dtype: object

# %%
series1 = pd.Series([1, 2, 3], index=["Cersei", "Masha", "Pasha"])
series2 = pd.Series([4, 5, 6], index=["Cersei", "Masha", "Pasha"])

# %%
pd.DataFrame({'col_1': series1, 'col_2': series2})
# Out:
#         col_1  col_2
# Cersei      1      4
# Masha       2      5
# Pasha       3      6

# %%
df_with_names['gender']
# Out:
# Cersei    female
# Masha       male
# Pasha       male
# Name: gender, dtype: object

# %%
df_with_names[['gender']]
# Out:
#         gender
# Cersei  female
# Masha     male
# Pasha     male

# %%
df.loc[:6]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df.size
# Out:
# 8000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.dtypes.value_counts()
# Out:
# object    5
# int64     3
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df.select_dtypes(include=object, exclude=int)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course
# 0                      none
# 1                 completed
# 2                      none
# ...

# %%
titanic = pd.read_csv('titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.dtypes.value_counts()
# Out:
# int64      5
# object     5
# float64    2
# Name: count, dtype: int64

# %%
df.gender == 'female'
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997     True
# 998     True
# 999     True
# Name: gender, Length: 1000, dtype: bool

# %%
df.loc[df.gender == 'female', ['gender', 'writing score']] # фильтрация
# Out:
#      gender  writing score
# 0    female             74
# 1    female             88
# 2    female             93
# 5    female             78
# 6    female             92
# ..      ...            ...
# 993  female             74
# 995  female             95
# 997  female             65
# 998  female             77
# 999  female             86
#
# [518 rows x 2 columns]

# %%
writing_score_mean = df['writing score'].mean()
writing_score_mean
# Out:
# 68.054

# %%
df[df['writing score'] > writing_score_mean]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df['lunch'].value_counts(normalize=True)
# Out:
# lunch
# standard        0.645
# free/reduced    0.355
# Name: proportion, dtype: float64

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df[df['lunch'] == 'free/reduced'].describe()
# Out:
#        math score  reading score  writing score
# count  355.000000     355.000000     355.000000
# mean    58.921127      64.653521      63.022535
# std     15.159956      14.895339      15.433823
# min      0.000000      17.000000      10.000000
# 25%     49.000000      56.000000      53.000000
# 50%     60.000000      65.000000      64.000000
# 75%     69.000000      75.000000      74.000000
# max    100.000000     100.000000     100.000000

# %%
df[df['lunch'] == 'standard'].describe()
# Out:
#        math score  reading score  writing score
# count  645.000000     645.000000     645.000000
# mean    70.034109      71.654264      70.823256
# std     13.653501      13.830602      14.339487
# min     19.000000      26.000000      22.000000
# 25%     61.000000      63.000000      62.000000
# 50%     69.000000      72.000000      72.000000
# 75%     80.000000      82.000000      81.000000
# max    100.000000     100.000000     100.000000

# %%
df.query("gender == 'female'")
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
gend = 'female'
df.query("gender == @gend")
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
score_columns = [i for i in df.columns if 'score' in i]
score_columns
# Out:
# ['math score', 'reading score', 'writing score']

# %%
df.filter(like='score')
# Out:
#      math score  reading score  writing score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
df_with_names.filter(like='sh', axis=0)
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# Masha   male        group A          associate's degree  free/reduced
# Pasha   male        group C                some college      standard
#
#       test preparation course  math score  reading score  writing score
# Masha                    none          47             57             44
# Pasha                    none          76             78             75

# %%
df.groupby(['gender', 'race/ethnicity'], as_index=False).agg(
    mean_math_score = ('math score', 'mean'),
    var_reading_score = ('reading score', 'var'))
# Out:
#    gender race/ethnicity  mean_math_score  var_reading_score
# 0  female        group A        58.527778         220.457143
# 1  female        group B        61.403846         213.528006
# 2  female        group C        62.033333         193.225947
# 3  female        group D        65.248062         193.622820
# 4  female        group E        70.811594         235.606564
# 5    male        group A        63.735849         238.736575
# 6    male        group B        65.930233         215.965116
# 7    male        group C        67.611511         176.666354
# 8    male        group D        69.413534         162.966393
# 9    male        group E        76.746479         195.068410

# %%
tr = df.groupby(['gender', 'race/ethnicity']).agg(
    mean_math_score = ('math score', 'mean'),
    var_reading_score = ('reading score', 'var'))
tr
# Out:
#                        mean_math_score  var_reading_score
# gender race/ethnicity
# female group A               58.527778         220.457143
#        group B               61.403846         213.528006
#        group C               62.033333         193.225947
#        group D               65.248062         193.622820
#        group E               70.811594         235.606564
# male   group A               63.735849         238.736575
#        group B               65.930233         215.965116
#        group C               67.611511         176.666354
#        group D               69.413534         162.966393
#        group E               76.746479         195.068410

# %%
tr.index
# Out:
# MultiIndex([('female', 'group A'),
#             ('female', 'group B'),
#             ('female', 'group C'),
#             ('female', 'group D'),
#             ('female', 'group E'),
#             (  'male', 'group A'),
#             (  'male', 'group B'),
#             (  'male', 'group C'),
#             (  'male', 'group D'),
#             (  'male', 'group E')],
#            names=['gender', 'race/ethnicity'])

# %%
tr.loc[[('female', 'group A'), ('female', 'group D')]]
# Out:
#                        mean_math_score  var_reading_score
# gender race/ethnicity
# female group A               58.527778         220.457143
#        group D               65.248062         193.622820

# %%
df.groupby(['gender', 'lunch']).agg('math score').nunique()
# Out:
# gender  lunch
# female  free/reduced    63
#         standard        65
# male    free/reduced    56
#         standard        59
# Name: math score, dtype: int64

# %%
df.sort_values(['gender', 'math score']) \
    .groupby('gender').head(5)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# 91     male        group C                 high school  free/reduced
# 327    male        group A                some college  free/reduced
# 76     male        group E            some high school      standard
# 596    male        group B                 high school  free/reduced
# 211    male        group C                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 59                     none           0             17             10
# ...

# %%
df['total_score'] = df['math score'] + df['reading score'] + df['writing score']
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score
# 0          218
# 1          247
# 2          278
# 3          148
# 4          229

# %%
df = df.assign(total_score_log = np.log(df['total_score']))
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df.drop(['total_score'], axis=1)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...
