# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('StudentsPerformance.csv')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df['math score'].hist()
# Out:
# <Axes: >

# %%
df.plot.scatter(x = 'math score', y = 'reading score')
# Out:
# <Axes: xlabel='math score', ylabel='reading score'>

# %%
sns.lmplot(x = 'math score', y = 'reading score', hue='gender', data=df);

# %%
ax = sns.lmplot(x = 'math score', y = 'reading score', hue='gender', data=df, fit_reg=False)
ax.set_xlabels("Math score")
ax.set_ylabels("Reading Score")

# %%
income = pd.read_csv('income.csv')
income
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
income['income'].plot()
# Out:
# <Axes: >

# %%
sns.lineplot(data=income)
# Out:
# <Axes: >

# %%
sns.lineplot(x=income.index, y=income.income)
# Out:
# <Axes: xlabel='None', ylabel='income'>

# %%
income.plot(kind='line')
# Out:
# <Axes: >

# %%
income.plot()
# Out:
# <Axes: >

# %%
plt.plot(income.index, income.income)

# %%
income.income.plot()
# Out:
# <Axes: >

# %%
sns.__version__
# Out:
# '0.13.2'

# %%
data = pd.read_csv("dataset_209770_6.txt", sep=" ")

# %%
data
# Out:
#               x            y
# 0    481.509758  1418.647399
# 1   1107.040427    92.442338
# 2    195.009717  1505.928420
# 3    501.634777  1401.722241
# 4   1395.722578   808.589701
# ..          ...          ...
# 85  1005.628540  1301.817639
# 86   193.256642  1509.047539
# 87    83.354148   498.819545
# 88  1296.336776   190.665780
# 89   183.724135  1488.356734
#
# [90 rows x 2 columns]

# %%
data.plot.scatter(x = 'x', y = 'y')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
sns.scatterplot(x=data.x, y=data.y)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
genome_matrix = pd.read_csv('genome_matrix.csv', index_col=0)

# %%
genome_matrix
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
genome_matrix.dtypes
# Out:
# species0    float64
# species1    float64
# species2    float64
# species3    float64
# species4    float64
# dtype: object

# %%
genome_matrix.iloc[:,1:]
# Out:
#    species0  species1  species2  species3  species4
# 0  0.536029  0.920292  0.679708  0.840606  0.430842
# 1  0.920292  0.862417  0.887593  0.769754  0.203214
# 2  0.679708  0.887593  0.595156  0.003435  0.096052
# 3  0.840606  0.769754  0.003435  0.458870  0.029251
# 4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
g = sns.heatmap(genome_matrix, cmap='viridis')# ваш код для создания теплокарты, укажите параметр cmap="viridis" для той же цветовой схемы
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
iris = pd.read_csv('iris.csv', index_col=0)
iris.head()
# Out:
#    sepal length  sepal width  petal length  petal width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
sns.kdeplot(data=iris)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.violinplot(data=iris)
# Out:
# <Axes: >

# %%
sns.violinplot(data=iris['petal length'])
# Out:
# <Axes: ylabel='petal length'>

# %%
iris.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 iris.columns()
#
# TypeError: 'Index' object is not callable

# %%
sns.pairplot(iris, hue='species')
